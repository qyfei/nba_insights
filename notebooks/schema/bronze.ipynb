# %%
# %sql
CREATE CATALOG IF NOT EXISTS nba_player_analysis;
CREATE SCHEMA IF NOT EXISTS nba_player_analysis.bronze;
CREATE TABLE IF NOT EXISTS nba_player_analysis.bronze.game (
    season_id                 BIGINT,
    team_id_home              BIGINT,
    team_abbreviation_home    STRING,
    team_name_home            STRING,
    game_id                   BIGINT,
    game_date                 STRING,
    matchup_home              STRING,
    wl_home                   STRING,
    min                       BIGINT,
    fgm_home                  DOUBLE,
    fga_home                  DOUBLE,
    fg_pct_home               DOUBLE,
    fg3m_home                 DOUBLE,
    fg3a_home                 DOUBLE,
    fg3_pct_home              DOUBLE,
    ftm_home                  DOUBLE,
    fta_home                  DOUBLE,
    ft_pct_home               DOUBLE,
    oreb_home                 DOUBLE,
    dreb_home                 DOUBLE,
    reb_home                  DOUBLE,
    ast_home                  DOUBLE,
    stl_home                  DOUBLE,
    blk_home                  DOUBLE,
    tov_home                  DOUBLE,
    pf_home                   DOUBLE,
    pts_home                  DOUBLE,
    plus_minus_home           BIGINT,
    video_available_home      BIGINT,
    team_id_away              BIGINT,
    team_abbreviation_away    STRING,
    team_name_away            STRING,
    matchup_away              STRING,
    wl_away                   STRING,
    fgm_away                  DOUBLE,
    fga_away                  DOUBLE,
    fg_pct_away               DOUBLE,
    fg3m_away                 DOUBLE,
    fg3a_away                 DOUBLE,
    fg3_pct_away              DOUBLE,
    ftm_away                  DOUBLE,
    fta_away                  DOUBLE,
    ft_pct_away               DOUBLE,
    oreb_away                 DOUBLE,
    dreb_away                 DOUBLE,
    reb_away                  DOUBLE,
    ast_away                  DOUBLE,
    stl_away                  DOUBLE,
    blk_away                  DOUBLE,
    tov_away                  DOUBLE,
    pf_away                   DOUBLE,
    pts_away                  DOUBLE,
    plus_minus_away           BIGINT,
    video_available_away      BIGINT,
    season_type               STRING
)
USING DELTA;

CREATE TABLE IF NOT EXISTS nba_player_analysis.bronze.inactive_players (
game_id                BIGINT,
player_id              BIGINT,
first_name            STRING,
last_name             STRING,
jersey_num           DOUBLE,
team_id                BIGINT,
team_city             STRING,
team_name             STRING,
team_abbreviation     STRING
) USING DELTA;
